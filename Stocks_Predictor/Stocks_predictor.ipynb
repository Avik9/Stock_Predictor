# %%
pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (19.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (0.8.1)
# Requirement already satisfied: requests>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas-datareader) (2.22.0)
# Requirement already satisfied: pandas>=0.21 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas-datareader) (0.25.3)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas-datareader) (4.3.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader) (1.25.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader) (2.8)
# Requirement already satisfied: pytz>=2017.2 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas>=0.21->pandas-datareader) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas>=0.21->pandas-datareader) (1.17.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas>=0.21->pandas-datareader) (2.8.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas>=0.21->pandas-datareader) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas_datareader
import datetime
import pandas_datareader.data as web
from pandas.plotting import autocorrelation_plot

# %%
start = datetime.datetime(1999, 1, 1)
end = datetime.datetime(2019, 11, 4)
amazon = web.DataReader("AMZN", 'av-daily-adjusted', start, end, api_key = "RWBEQKLG65YPF62U")

# %%
amazon['open'].plot(label="Open")
amazon['close'].plot(label="Close")
amazon['high'].plot(label="High", figsize=(30, 10))
amazon['low'].plot(label="Low")
plt.legend()

plt.show()

# %%
# Upon looking at the sudden drop in value for the stock price amount over the years mentioned above at this ^ 
# really had me questioning about what was going on so I zoomed in on the graph to see what happened on that day.

# %%
start = datetime.datetime(2018, 12, 2)
end = datetime.datetime(2018, 12, 30)
amazon = web.DataReader("AMZN", 'av-daily-adjusted', start, end, api_key = "RWBEQKLG65YPF62U")

# %%
amazon['open'].plot(label="Open")
amazon['close'].plot(label="Close")
amazon['high'].plot(label="High", figsize=(30, 10))
amazon['low'].plot(label="Low")
plt.legend()

plt.show()

# %%
# I realized that it crashed around Christmas of 2018 and so I explored the news of what was happening then and I found
# the reason why there is such a huge drop for December 25th 2018 is specified here:
# Amazon Alexa crashes after Christmas Day overload
# https://www.theguardian.com/technology/2018/dec/26/amazon-alexa-echo-crashes-christmas-day-overload
